# %% [markdown]
# # Unemployment Rate in Australia from 2018 to 2020

# %%
#%matplotlib notebook

# %%
# Dependencies
import requests
from pprint import pprint
from config import vic_key
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from datetime import datetime
from scipy import stats
import scipy.stats as st
import datetime
url = "https://api.vic.gov.au:443/abs/v1.0/labour-force-statistics?"

# %%
#fliter
params = {
'region': "AUSTRALIA",
'data_item': "UNEMPLOYMENT_RATE",
'age': "15_AND_OVER",
'start_period': "2018-01",
'end_period': "2020-12"
}

# %%
headers = {
  "Content-Type": "application/json",
  "Accept": "application/json",
  "apikey": vic_key
}

# %%
# Request data
response = requests.get(url, headers = headers, params = params)
# Converting the response to JSON, and printing the result.
data = response.json()
pprint(data)
# Out:
# {'_links': [{'href': '/abs/v1.0/labour-force-statistics?age=15_AND_OVER&data_item=UNEMPLOYMENT_RATE&end_period=2020-12&region=AUSTRALIA&start_period=2018-01&page=1&limit=1000',
#              'rel': 'self'},
#             {'href': '/abs/v1.0/labour-force-statistics?age=15_AND_OVER&data_item=UNEMPLOYMENT_RATE&end_period=2020-12&region=AUSTRALIA&start_period=2018-01&page=1&limit=1000',
#              'rel': 'first'},
#             {'href': '/abs/v1.0/labour-force-statistics?age=15_AND_OVER&data_item=UNEMPLOYMENT_RATE&end_period=2020-12&region=AUSTRALIA&start_period=2018-01&page=1&limit=1000',
#              'rel': 'last'}],
#  '_meta': {'count': 324,
#            'limit': 1000,
#            'page': 1,
#            'response_time': '1.55 seconds',
#            'response_time_ms': 1550,
#            'total_records': 324},
#  'labour_force_statistics': [{'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-01',
#                               'observation_value': '5.8914575',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-02',
#                               'observation_value': '5.8682949',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-03',
#                               'observation_value': '5.7280693',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-04',
#                               'observation_value': '5.5032532',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-05',
#                               'observation_value': '5.2036866',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-06',
#                               'observation_value': '5.3224227',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-07',
#                               'observation_value': '5.3110662',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-08',
#                               'observation_value': '5.2359678',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-09',
#                               'observation_value': '4.8164909',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-10',
#                               'observation_value': '4.7850506',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-11',
#                               'observation_value': '4.8530436',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-12',
#                               'observation_value': '4.8639039',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-01',
#                               'observation_value': '5.331432',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-02',
#                               'observation_value': '5.2700483',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-03',
#                               'observation_value': '5.3128126',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-04',
#                               'observation_value': '5.1777032',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-05',
#                               'observation_value': '5.1027087',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-06',
#                               'observation_value': '5.0442512',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-07',
#                               'observation_value': '5.2058217',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-08',
#                               'observation_value': '5.3645705',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-09',
#                               'observation_value': '5.3722145',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-10',
#                               'observation_value': '5.2346194',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-11',
#                               'observation_value': '4.9422714',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-12',
#                               'observation_value': '5.1221102',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-01',
#                               'observation_value': '5.7799535',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-02',
#                               'observation_value': '5.5751774',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-03',
#                               'observation_value': '5.5334444',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-04',
#                               'observation_value': '6.5863271',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-05',
#                               'observation_value': '6.9327189',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-06',
#                               'observation_value': '7.2659339',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-07',
#                               'observation_value': '7.4563939',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-08',
#                               'observation_value': '7.0791994',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-09',
#                               'observation_value': '7.1123649',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-10',
#                               'observation_value': '6.6745759',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-11',
#                               'observation_value': '6.2002822',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Original',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-12',
#                               'observation_value': '6.5195664',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-01',
#                               'observation_value': '5.4261773',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-02',
#                               'observation_value': '5.5029025',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-03',
#                               'observation_value': '5.4896702',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-04',
#                               'observation_value': '5.5852099',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-05',
#                               'observation_value': '5.408063',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-06',
#                               'observation_value': '5.5106818',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-07',
#                               'observation_value': '5.3304754',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-08',
#                               'observation_value': '5.2025094',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-09',
#                               'observation_value': '4.8321972',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-10',
#                               'observation_value': '4.9707687',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-11',
#                               'observation_value': '5.134056',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-12',
#                               'observation_value': '4.9522846',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-01',
#                               'observation_value': '4.9280885',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-02',
#                               'observation_value': '4.9513109',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-03',
#                               'observation_value': '5.0881428',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-04',
#                               'observation_value': '5.250262',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-05',
#                               'observation_value': '5.3125777',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-06',
#                               'observation_value': '5.2349942',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-07',
#                               'observation_value': '5.2243948',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-08',
#                               'observation_value': '5.3237174',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-09',
#                               'observation_value': '5.3771051',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-10',
#                               'observation_value': '5.4430369',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-11',
#                               'observation_value': '5.2247253',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-12',
#                               'observation_value': '5.209313',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-01',
#                               'observation_value': '5.3480538',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-02',
#                               'observation_value': '5.2266947',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-03',
#                               'observation_value': '5.298259',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-04',
#                               'observation_value': '6.6738348',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-05',
#                               'observation_value': '7.179612',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-06',
#                               'observation_value': '7.5183695',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-07',
#                               'observation_value': '7.4699767',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-08',
#                               'observation_value': '7.0255557',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-09',
#                               'observation_value': '7.1210894',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-10',
#                               'observation_value': '6.9488604',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-11',
#                               'observation_value': '6.5343362',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Seasonally '
#                                                              'Adjusted',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-12',
#                               'observation_value': '6.6583414',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-01',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-02',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-03',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-04',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-05',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-06',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-07',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-08',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-09',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-10',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-11',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-12',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-01',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-02',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-03',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-04',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-05',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-06',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-07',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-08',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-09',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-10',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-11',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Males'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-12',
#                               'observation_value': 'NaN',
# ...
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-02',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-03',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-04',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-05',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-06',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-07',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-08',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-09',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-10',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-11',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2018-12',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-01',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-02',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-03',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-04',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-05',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-06',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-07',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-08',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-09',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-10',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-11',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2019-12',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-01',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-02',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-03',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-04',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-05',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-06',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-07',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-08',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-09',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-10',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-11',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'},
#                              {'adjustment_type_description': 'Trend',
#                               'age_description': '15 and over',
#                               'data_item_description': 'Unemployment rate (%)',
#                               'observation_month': '2020-12',
#                               'observation_value': 'NaN',
#                               'region_description': 'Australia',
#                               'sex_description': 'Persons'}]}

# %%
data1 = data['labour_force_statistics']

# %%
unemployment_aus_df = pd.DataFrame(data1)
clean_unemployment_aus_df = unemployment_aus_df[unemployment_aus_df.observation_value != 'NaN']
clean_unemployment_aus_df["observation_value"] = clean_unemployment_aus_df.observation_value.astype(float)
clean_unemployment_aus_df
# Out:
# <ipython-input-7-c208b77c098c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_unemployment_aus_df["observation_value"] = clean_unemployment_aus_df.observation_value.astype(float)
#     region_description  data_item_description sex_description age_description  \
# 0            Australia  Unemployment rate (%)           Males     15 and over
# 1            Australia  Unemployment rate (%)           Males     15 and over
# 2            Australia  Unemployment rate (%)           Males     15 and over
# 3            Australia  Unemployment rate (%)           Males     15 and over
# 4            Australia  Unemployment rate (%)           Males     15 and over
# ..                 ...                    ...             ...             ...
# 283          Australia  Unemployment rate (%)         Persons     15 and over
# 284          Australia  Unemployment rate (%)         Persons     15 and over
# 285          Australia  Unemployment rate (%)         Persons     15 and over
# 286          Australia  Unemployment rate (%)         Persons     15 and over
# 287          Australia  Unemployment rate (%)         Persons     15 and over
#
#     adjustment_type_description observation_month  observation_value
# 0                      Original           2018-01           5.891457
# 1                      Original           2018-02           5.868295
# 2                      Original           2018-03           5.728069
# 3                      Original           2018-04           5.503253
# 4                      Original           2018-05           5.203687
# ..                          ...               ...                ...
# 283         Seasonally Adjusted           2020-08           6.804698
# 284         Seasonally Adjusted           2020-09           6.909572
# 285         Seasonally Adjusted           2020-10           6.980306
# 286         Seasonally Adjusted           2020-11           6.817515
# 287         Seasonally Adjusted           2020-12           6.589865
#
# [216 rows x 7 columns]

# %%
clean_unemployment_aus_df.dtypes
# Out:
# region_description              object
# data_item_description           object
# sex_description                 object
# age_description                 object
# adjustment_type_description     object
# observation_month               object
# observation_value              float64
# dtype: object

# %%
# Extract individual Without genders
generaldf = clean_unemployment_aus_df.loc[clean_unemployment_aus_df["sex_description"] == "Persons"]
generaldf
# Out:
#     region_description  data_item_description sex_description age_description  \
# 216          Australia  Unemployment rate (%)         Persons     15 and over
# 217          Australia  Unemployment rate (%)         Persons     15 and over
# 218          Australia  Unemployment rate (%)         Persons     15 and over
# 219          Australia  Unemployment rate (%)         Persons     15 and over
# 220          Australia  Unemployment rate (%)         Persons     15 and over
# ..                 ...                    ...             ...             ...
# 283          Australia  Unemployment rate (%)         Persons     15 and over
# 284          Australia  Unemployment rate (%)         Persons     15 and over
# 285          Australia  Unemployment rate (%)         Persons     15 and over
# 286          Australia  Unemployment rate (%)         Persons     15 and over
# 287          Australia  Unemployment rate (%)         Persons     15 and over
#
#     adjustment_type_description observation_month  observation_value
# 216                    Original           2018-01           5.961396
# 217                    Original           2018-02           6.042301
# 218                    Original           2018-03           5.860192
# 219                    Original           2018-04           5.582364
# 220                    Original           2018-05           5.289476
# ..                          ...               ...                ...
# 283         Seasonally Adjusted           2020-08           6.804698
# 284         Seasonally Adjusted           2020-09           6.909572
# 285         Seasonally Adjusted           2020-10           6.980306
# 286         Seasonally Adjusted           2020-11           6.817515
# 287         Seasonally Adjusted           2020-12           6.589865
#
# [72 rows x 7 columns]

# %%
# Extract individual Without genders
general1=generaldf.loc[generaldf["adjustment_type_description"] == "Seasonally Adjusted"]
general1.head()
# Out:
#     region_description  data_item_description sex_description age_description  \
# 252          Australia  Unemployment rate (%)         Persons     15 and over
# 253          Australia  Unemployment rate (%)         Persons     15 and over
# 254          Australia  Unemployment rate (%)         Persons     15 and over
# 255          Australia  Unemployment rate (%)         Persons     15 and over
# 256          Australia  Unemployment rate (%)         Persons     15 and over
#
#     adjustment_type_description observation_month  observation_value
# 252         Seasonally Adjusted           2018-01           5.501085
# 253         Seasonally Adjusted           2018-02           5.559338
# 254         Seasonally Adjusted           2018-03           5.505104
# 255         Seasonally Adjusted           2018-04           5.534267
# 256         Seasonally Adjusted           2018-05           5.406442

# %%
# Remove unecessary columns from the DataFrame and save the new DataFrame
# Only keep: "isbn", "original_publication_year", "original_title", "authors",
# "ratings_1", "ratings_2", "ratings_3", "ratings_4", "ratings_5"
reduced_df = general1[["observation_month", "observation_value",]]
reduced_df.head()
# Out:
#     observation_month  observation_value
# 252           2018-01           5.501085
# 253           2018-02           5.559338
# 254           2018-03           5.505104
# 255           2018-04           5.534267
# 256           2018-05           5.406442

# %%
# Rename the headers to be more explanatory
renamed_df = reduced_df.rename(columns={"observation_month": "Quarter", "observation_value": "rate (%)"})
renamed_df.dtypes
# Out:
# Quarter      object
# rate (%)    float64
# dtype: object

# %%
renamed_df['Quarter']= pd.to_datetime(renamed_df['Quarter'])
renamed_df
# Out:
#        Quarter  rate (%)
# 252 2018-01-01  5.501085
# 253 2018-02-01  5.559338
# 254 2018-03-01  5.505104
# 255 2018-04-01  5.534267
# 256 2018-05-01  5.406442
# 257 2018-06-01  5.318580
# 258 2018-07-01  5.275815
# 259 2018-08-01  5.257135
# 260 2018-09-01  5.015530
# 261 2018-10-01  5.002688
# 262 2018-11-01  5.098609
# 263 2018-12-01  5.009500
# 264 2019-01-01  5.041164
# 265 2019-02-01  4.956326
# 266 2019-03-01  5.079308
# 267 2019-04-01  5.216677
# 268 2019-05-01  5.224588
# 269 2019-06-01  5.248259
# 270 2019-07-01  5.245523
# 271 2019-08-01  5.244474
# 272 2019-09-01  5.199313
# 273 2019-10-01  5.297781
# 274 2019-11-01  5.139451
# 275 2019-12-01  5.050057
# 276 2020-01-01  5.263393
# 277 2020-02-01  5.076525
# 278 2020-03-01  5.218752
# 279 2020-04-01  6.352233
# 280 2020-05-01  7.060638
# 281 2020-06-01  7.433706
# 282 2020-07-01  7.478235
# 283 2020-08-01  6.804698
# 284 2020-09-01  6.909572
# 285 2020-10-01  6.980306
# 286 2020-11-01  6.817515
# 287 2020-12-01  6.589865

# %%
renamed_df['Quarter'] = pd.to_datetime(renamed_df['Quarter'])
renamed_df.dtypes
renamed_df
renamed_df = renamed_df.set_index("Quarter")

# %%
Quarterly_resampled_data = renamed_df.resample('Q').mean()
Quarterly_resampled_data
# Out:
#             rate (%)
# Quarter
# 2018-03-31  5.521843
# 2018-06-30  5.419763
# 2018-09-30  5.182827
# 2018-12-31  5.036932
# 2019-03-31  5.025599
# 2019-06-30  5.229841
# 2019-09-30  5.229770
# 2019-12-31  5.162430
# 2020-03-31  5.186223
# 2020-06-30  6.948859
# 2020-09-30  7.064168
# 2020-12-31  6.795895

# %%
#Quarterly_resampled_data = renamed_df.resample('Q').mean() 
#df = renamed_df.resample('Q', how='mean', axis=1)

# %%
#renamed_df.resample('Q', axis=0)

# %%
Quarterly_resampled_data.plot(kind="line")

plt.xlabel("Quarters")
plt.ylabel("Rate (%)")
plt.title("Unemployment Rate")
plt.show()

# %% [markdown]
# # Inflation Rate in Australia from 2018 to 2020

# %%
# File to Load (Remember to Change These)
csv_file = os.path.join('..', 'Phillips curve', 'CPIquarterly.csv')

CPI_df = pd.read_csv(csv_file) 
CPI_df.dtypes
# Out:
# Quarter                              object
# Change from previous quarter (%)    float64
# dtype: object

# %%
CPI_df['Quarter']= pd.to_datetime(CPI_df['Quarter'])
CPI_df
# Out:
#       Quarter  Change from previous quarter (%)
# 0  2018-03-31                               0.4
# 1  2018-06-30                               0.4
# 2  2018-09-30                               0.4
# 3  2018-12-31                               0.5
# 4  2019-03-31                               0.0
# 5  2019-06-30                               0.6
# 6  2019-09-30                               0.5
# 7  2019-12-31                               0.7
# 8  2020-03-31                               0.3
# 9  2020-06-30                              -1.9
# 10 2020-09-30                               1.6
# 11 2020-12-31                               0.9

# %%
CPI_df = CPI_df.rename(columns={"Change from previous quarter (%)": "CPI %"})
CPI_df = CPI_df.set_index("Quarter")
CPI_df
# Out:
#             CPI %
# Quarter
# 2018-03-31    0.4
# 2018-06-30    0.4
# 2018-09-30    0.4
# 2018-12-31    0.5
# 2019-03-31    0.0
# 2019-06-30    0.6
# 2019-09-30    0.5
# 2019-12-31    0.7
# 2020-03-31    0.3
# 2020-06-30   -1.9
# 2020-09-30    1.6
# 2020-12-31    0.9

# %%
CPI_df.plot(kind="line")

plt.xlabel("Quarters")
plt.ylabel("CPI %")
plt.title("Inflation Rate")
plt.show()

# %% [markdown]
# # Phillips curve

# %%
inner_merged = pd.merge(Quarterly_resampled_data, CPI_df,left_on=['Quarter'],
              right_on=['Quarter'],
              how='inner')
inner_merged
# Out:
#             rate (%)  CPI %
# Quarter
# 2018-03-31  5.954630    0.4
# 2018-06-30  5.348471    0.4
# 2018-09-30  5.120439    0.4
# 2018-12-31  4.775880    0.5
# 2019-03-31  5.415351    0.0
# 2019-06-30  5.155026    0.6
# 2019-09-30  5.171211    0.5
# 2019-12-31  4.894487    0.7
# 2020-03-31  5.588659    0.3
# 2020-06-30  6.852192   -1.9
# 2020-09-30  6.988540    1.6
# 2020-12-31  6.432596    0.9

# %%
inner_merged.plot(kind='scatter', x='rate (%)', y='CPI %')
plt.minorticks_on()
plt.title("Phillips curve")
plt.xlabel("Unemployment Rate")
plt.ylabel("Inflation Rate")
plt.grid(True)
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.show()

# %%
# Create a scatter plot based on new dataframe 
plt.scatter(inner_merged['rate (%)'], inner_merged['CPI %'], marker = "*")

# Add labels and title to plot
plt.title("Phillips curve")
plt.xlabel("Unemployment % ")
plt.ylabel("Inflation %")
plt.grid(True)
plt.grid(which='major', linestyle='-')
plt.grid(which='minor', linestyle=':')
plt.minorticks_on()
# Display plot
plt.show()

# %% [markdown]
# # Correlation and Regression

# %%
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = -0.18x +1.4

# %%
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel("Unemployment Rate")
plt.ylabel("Inflation Rate")

# Annotate linear regression
plt.annotate(line_eq,(5,-1),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.savefig("output_data/Correlation and Regression.png")
plt.show()
# Out:
# The r-value is: 0.028446078793564478

# %%
# We then compute the Pearson correlation coefficient between "Unemployment %" and "Inflation %"
correlation = st.pearsonr(x_values,y_values)
print(f"The correlation between Unemployment % and Inflation % is {round(correlation[0],2)}")
# Out:
# The correlation between Unemployment % and Inflation % is -0.17

# %% [raw]
# The Phillips curve is an economic concept developed by A. W. Phillips stating that inflation and unemployment have a stable and inverse relationship.
